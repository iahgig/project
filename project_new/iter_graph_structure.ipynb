# %%
import matplotlib.pyplot as plt
iter_num=list(range(1,7))

# %% [markdown]
# Swat

# %%
prec=[0.2 ,0.9907   ,      0.9907      ,   0.9923    ,     0.9923    ,     0.9923]
rec=[0.46421671 ,0.64582769 ,0.64582769 ,0.67707348, 0.67707348 ,0.68374015]
f1=[0.58324819 ,0.76877717 ,0.76877717 ,0.79458327, 0.79458327 ,0.80013883]
plt.plot(iter_num,prec,label='Prec')
plt.plot(iter_num,rec,label='Rec')
plt.plot(iter_num,f1,label='F1')
plt.xlabel('Number of iterations')
plt.xticks(iter_num)
plt.title("Swat")
plt.legend()
plt.show()

# %%
prec=[0.86666667 ,0.9907   ,      0.9907      ,   0.9923    ,     0.9923    ,     0.9923]
rec=[0.46421671 ,0.64582769 ,0.64582769 ,0.67707348, 0.67707348 ,0.68374015]
f1=[0.58324819 ,0.76877717 ,0.76877717 ,0.79458327, 0.79458327 ,0.80013883]
plt.plot(iter_num,prec,label='Prec')
plt.plot(iter_num,rec,label='Rec')
plt.plot(iter_num,f1,label='F1')
plt.xlabel('Number of iterations')
plt.xticks(iter_num)
plt.title("Swat")
plt.legend()
plt.show()

# %%
import numpy as np
prec=[  0.      ,   0.50818798, 0.50585803 ,0.82537436, 0.89365468,0.89365468]
rec=[    0. ,        0.71946221, 0.36949299 ,0.71583783, 0.68020981,0.68020981]
prec=np.array(prec)
rec=np.array(rec)
f1=2*prec*rec/(prec+rec)
plt.plot(iter_num,prec,label='Prec')
plt.plot(iter_num,rec,label='Rec')
plt.plot(iter_num,f1,label='F1')
plt.xlabel('Number of iterations')
plt.xticks(iter_num)
plt.title("Wadi")
plt.legend()
plt.show()
# Out:
# <ipython-input-4-d67e0303c1ed>:6: RuntimeWarning: invalid value encountered in true_divide
#   f1=2*prec*rec/(prec+rec)

# %%
import numpy as np
import matplotlib.pyplot as plt
prec=[  0.23725719,    0.28895503  ,     0.31339031, 0.47895045 ,0.93428363, 0.93428363 ]
rec=[    0.10833333 ,  0.13042328 ,0.13981481   , 0.21694847,0.69432367 ,0.69432367 ]
prec=np.array(prec)
rec=np.array(rec)
f1=2*prec*rec/(prec+rec)
print(f1)

plt.plot(iter_num,prec,label='Prec')
plt.plot(iter_num,rec,label='Rec')
plt.plot(iter_num,f1,label='F1')
plt.xlabel('Number of iterations')
plt.xticks(iter_num)
plt.title("Wadi")
plt.legend()
plt.show()
# Out:
# [0.14874749 0.17972538 0.19336325 0.29862833 0.79662573 0.79662573]

# %%
import numpy as np
prec=[0.81397929 ,0.81334971, 0.91743831, 0.99087834 ,0.99087834,0.99087834]
rec=[0.96030531 , 0.99273903, 0.99276694, 0.99270777, 0.99538715,0.99676077,]
prec=np.array(prec)
rec=np.array(rec)
f1=2*prec*rec/(prec+rec)
print(f1)

plt.plot(iter_num,prec,label='Prec')
plt.plot(iter_num,rec,label='Rec')
plt.plot(iter_num,f1,label='F1')
plt.xlabel('Number of iterations')
plt.xticks(iter_num)
plt.title("KDDCUP99")
plt.legend()
plt.show()
# Out:
# [0.88110851 0.89413547 0.95361734 0.99179221 0.99312763 0.99381085]
